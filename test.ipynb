# %%
import json
from parsing.parsers import *
data = json.loads(open('piecewise.json').read())

for curve in data['curves']:
    config = curve['curveConfig']
    for rateHelper in config['rateHelpers']:
        values = parse(**rateHelper['helperConfig'])
        print(values)
# Out:
# {'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403d4a0> >, 'tenor': Period("1D"), 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e340> >, 'settlementDays': 0, 'endOfMonth': False, 'convention': 4}
# {'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f10270> >, 'tenor': Period("2M"), 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12dc0> >, 'settlementDays': 0, 'endOfMonth': False, 'convention': 4}
# {'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403c9c0> >, 'tenor': Period("3M"), 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403def0> >, 'settlementDays': 0, 'endOfMonth': False, 'convention': 4}
# {'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f127c0> >, 'tenor': Period("6M"), 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12640> >, 'settlementDays': 0, 'endOfMonth': False, 'convention': 4}
# {'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403d4a0> >, 'tenor': Period("9M"), 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e340> >, 'settlementDays': 0, 'endOfMonth': False, 'convention': 4}
# {'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f10270> >, 'tenor': Period("12M"), 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12dc0> >, 'settlementDays': 0, 'endOfMonth': False, 'convention': 4}
# {'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403c9c0> >, 'tenor': Period("18M"), 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403def0> >, 'settlementDays': 0, 'endOfMonth': False, 'convention': 4}
# {'tenor': Period("2Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12850> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12640> >, 'convention': 1, 'endOfMonth': True, 'frequency': 2, 'settlementDays': 2, 'paymentLag': 0, 'telescopicValueDates': True, 'discountCurve': 'CLP_COLLUSD', 'index': 'ICP', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("3Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403d620> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e340> >, 'convention': 1, 'endOfMonth': True, 'frequency': 2, 'settlementDays': 2, 'paymentLag': 0, 'telescopicValueDates': True, 'discountCurve': 'CLP_COLLUSD', 'index': 'ICP', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("4Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12640> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12850> >, 'convention': 1, 'endOfMonth': True, 'frequency': 2, 'settlementDays': 2, 'paymentLag': 0, 'telescopicValueDates': True, 'discountCurve': 'CLP_COLLUSD', 'index': 'ICP', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("5Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403d3e0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403def0> >, 'convention': 1, 'endOfMonth': True, 'frequency': 2, 'settlementDays': 2, 'paymentLag': 0, 'telescopicValueDates': True, 'discountCurve': 'CLP_COLLUSD', 'index': 'ICP', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("6Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12850> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12640> >, 'convention': 1, 'endOfMonth': True, 'frequency': 2, 'settlementDays': 2, 'paymentLag': 0, 'telescopicValueDates': True, 'discountCurve': 'CLP_COLLUSD', 'index': 'ICP', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("7Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403d620> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e340> >, 'convention': 1, 'endOfMonth': True, 'frequency': 2, 'settlementDays': 2, 'paymentLag': 0, 'telescopicValueDates': True, 'discountCurve': 'CLP_COLLUSD', 'index': 'ICP', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("8Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12640> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12850> >, 'convention': 1, 'endOfMonth': True, 'frequency': 2, 'settlementDays': 2, 'paymentLag': 0, 'telescopicValueDates': True, 'discountCurve': 'CLP_COLLUSD', 'index': 'ICP', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("9Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403d3e0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403def0> >, 'convention': 1, 'endOfMonth': True, 'frequency': 2, 'settlementDays': 2, 'paymentLag': 0, 'telescopicValueDates': True, 'discountCurve': 'CLP_COLLUSD', 'index': 'ICP', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("10Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12850> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12640> >, 'convention': 1, 'endOfMonth': True, 'frequency': 2, 'settlementDays': 2, 'paymentLag': 0, 'telescopicValueDates': True, 'discountCurve': 'CLP_COLLUSD', 'index': 'ICP', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("15Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403d620> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e340> >, 'convention': 1, 'endOfMonth': True, 'frequency': 2, 'settlementDays': 2, 'paymentLag': 0, 'telescopicValueDates': True, 'discountCurve': 'CLP_COLLUSD', 'index': 'ICP', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("20Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12640> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12850> >, 'convention': 1, 'endOfMonth': True, 'frequency': 2, 'settlementDays': 2, 'paymentLag': 0, 'telescopicValueDates': True, 'discountCurve': 'CLP_COLLUSD', 'index': 'ICP', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("25Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403d3e0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403def0> >, 'convention': 1, 'endOfMonth': True, 'frequency': 2, 'settlementDays': 2, 'paymentLag': 0, 'telescopicValueDates': True, 'discountCurve': 'CLP_COLLUSD', 'index': 'ICP', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("30Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12850> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12640> >, 'convention': 1, 'endOfMonth': True, 'frequency': 2, 'settlementDays': 2, 'paymentLag': 0, 'telescopicValueDates': True, 'discountCurve': 'CLP_COLLUSD', 'index': 'ICP', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403ca80> >, 'tenor': Period("1D"), 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e340> >, 'settlementDays': 0, 'endOfMonth': False, 'convention': 4}
# {'tenor': Period("1W"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12640> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12850> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("2W"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403d3e0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403def0> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("3W"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12850> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12640> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("1M"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403e310> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e340> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("2M"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12640> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12850> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("3M"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403d3e0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403def0> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("4M"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12850> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12640> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("5M"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403e310> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e340> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("6M"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12640> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12850> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("7M"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403d3e0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403def0> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("8M"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12850> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12640> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("9M"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403e310> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e340> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("10M"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12640> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12850> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("11M"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403d3e0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403def0> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("12M"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12850> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12640> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("18M"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403e310> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e340> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("2Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12640> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12850> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("3Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403d3e0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403def0> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("4Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12850> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12640> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("5Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403e310> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e340> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("6Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12640> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12850> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("7Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403d3e0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403def0> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("8Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12850> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12640> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("9Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403e310> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e340> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("10Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12640> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12850> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("12Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403d3e0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403def0> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("15Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12850> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12640> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("20Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403e310> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e340> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("25Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12640> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12850> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("30Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403d3e0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403def0> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("40Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12850> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12640> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("50Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403e310> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e340> >, 'convention': 0, 'endOfMonth': True, 'frequency': 1, 'settlementDays': 2, 'paymentLag': 2, 'telescopicValueDates': True, 'index': 'SOFR', 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103eec3c0> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': False, 'convention': 0, 'collateralCurve': 'CLP_COLLUSD', 'endDate': Date(9,3,2023), 'settlementDays': 0}
# {'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e2b0> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': False, 'convention': 0, 'collateralCurve': 'CLP_COLLUSD', 'endDate': Date(9,4,2023), 'settlementDays': 0}
# {'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103eec3c0> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': False, 'convention': 0, 'collateralCurve': 'CLP_COLLUSD', 'endDate': Date(9,5,2023), 'settlementDays': 0}
# {'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e310> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': False, 'convention': 0, 'collateralCurve': 'CLP_COLLUSD', 'endDate': Date(9,6,2023), 'settlementDays': 0}
# {'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403def0> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': False, 'convention': 0, 'collateralCurve': 'CLP_COLLUSD', 'endDate': Date(9,7,2023), 'settlementDays': 0}
# {'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e2b0> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': False, 'convention': 0, 'collateralCurve': 'CLP_COLLUSD', 'endDate': Date(9,8,2023), 'settlementDays': 0}
# {'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103eed830> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': False, 'convention': 0, 'collateralCurve': 'CLP_COLLUSD', 'endDate': Date(9,9,2023), 'settlementDays': 0}
# {'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e310> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': False, 'convention': 0, 'collateralCurve': 'CLP_COLLUSD', 'endDate': Date(9,10,2023), 'settlementDays': 0}
# {'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403d4a0> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': False, 'convention': 0, 'collateralCurve': 'CLP_COLLUSD', 'endDate': Date(9,11,2023), 'settlementDays': 0}
# {'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e2b0> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': False, 'convention': 0, 'collateralCurve': 'CLP_COLLUSD', 'endDate': Date(9,12,2023), 'settlementDays': 0}
# {'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103eec3c0> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': False, 'convention': 0, 'collateralCurve': 'CLP_COLLUSD', 'endDate': Date(9,1,2024), 'settlementDays': 0}
# {'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e310> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': False, 'convention': 0, 'collateralCurve': 'CLP_COLLUSD', 'endDate': Date(9,2,2024), 'settlementDays': 0}
# {'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403ca80> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': False, 'convention': 0, 'collateralCurve': 'CLP_COLLUSD', 'endDate': Date(9,3,2024), 'settlementDays': 0}
# {'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e2b0> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': False, 'convention': 0, 'collateralCurve': 'CLP_COLLUSD', 'endDate': Date(9,4,2024), 'settlementDays': 0}
# {'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103eed830> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': False, 'convention': 0, 'collateralCurve': 'CLP_COLLUSD', 'endDate': Date(9,5,2024), 'settlementDays': 0}
# {'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e310> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': False, 'convention': 0, 'collateralCurve': 'CLP_COLLUSD', 'endDate': Date(9,6,2024), 'settlementDays': 0}
# {'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403def0> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': False, 'convention': 0, 'collateralCurve': 'CLP_COLLUSD', 'endDate': Date(9,7,2024), 'settlementDays': 0}
# {'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e2b0> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': False, 'convention': 0, 'collateralCurve': 'CLP_COLLUSD', 'endDate': Date(9,8,2024), 'settlementDays': 0}
# {'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103eec3c0> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': False, 'convention': 0, 'collateralCurve': 'CLP_COLLUSD', 'endDate': Date(9,9,2024), 'settlementDays': 0}
# {'tenor': Period("2Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403e340> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12d00> >, 'convention': 1, 'endOfMonth': False, 'settlementDays': 2, 'discountCurve': 'CLP_COLLUSD', 'index': 'ICP', 'fixedLegCurrency': <ORE.ORE.CLFCurrency; proxy of <Swig Object of type 'QuantExt::CLFCurrency *' at 0x103f12850> >, 'fwdStart': Period("0D"), 'fixedLegFrequency': 2}
# {'tenor': Period("3Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103eed830> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x104071e90> >, 'convention': 1, 'endOfMonth': False, 'settlementDays': 2, 'discountCurve': 'CLP_COLLUSD', 'index': 'ICP', 'fixedLegCurrency': <ORE.ORE.CLFCurrency; proxy of <Swig Object of type 'QuantExt::CLFCurrency *' at 0x1040734b0> >, 'fwdStart': Period("0D"), 'fixedLegFrequency': 2}
# {'tenor': Period("4Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f125e0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f10270> >, 'convention': 1, 'endOfMonth': False, 'settlementDays': 2, 'discountCurve': 'CLP_COLLUSD', 'index': 'ICP', 'fixedLegCurrency': <ORE.ORE.CLFCurrency; proxy of <Swig Object of type 'QuantExt::CLFCurrency *' at 0x10403e2b0> >, 'fwdStart': Period("0D"), 'fixedLegFrequency': 2}
# {'tenor': Period("5Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x104072b20> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103eed830> >, 'convention': 1, 'endOfMonth': False, 'settlementDays': 2, 'discountCurve': 'CLP_COLLUSD', 'index': 'ICP', 'fixedLegCurrency': <ORE.ORE.CLFCurrency; proxy of <Swig Object of type 'QuantExt::CLFCurrency *' at 0x10403d4a0> >, 'fwdStart': Period("0D"), 'fixedLegFrequency': 2}
# {'tenor': Period("6Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403e340> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12d00> >, 'convention': 1, 'endOfMonth': False, 'settlementDays': 2, 'discountCurve': 'CLP_COLLUSD', 'index': 'ICP', 'fixedLegCurrency': <ORE.ORE.CLFCurrency; proxy of <Swig Object of type 'QuantExt::CLFCurrency *' at 0x103f12850> >, 'fwdStart': Period("0D"), 'fixedLegFrequency': 2}
# {'tenor': Period("7Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103eec3c0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x104071e90> >, 'convention': 1, 'endOfMonth': False, 'settlementDays': 2, 'discountCurve': 'CLP_COLLUSD', 'index': 'ICP', 'fixedLegCurrency': <ORE.ORE.CLFCurrency; proxy of <Swig Object of type 'QuantExt::CLFCurrency *' at 0x1040734b0> >, 'fwdStart': Period("0D"), 'fixedLegFrequency': 2}
# {'tenor': Period("8Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f125e0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f10270> >, 'convention': 1, 'endOfMonth': False, 'settlementDays': 2, 'discountCurve': 'CLP_COLLUSD', 'index': 'ICP', 'fixedLegCurrency': <ORE.ORE.CLFCurrency; proxy of <Swig Object of type 'QuantExt::CLFCurrency *' at 0x10403e2b0> >, 'fwdStart': Period("0D"), 'fixedLegFrequency': 2}
# {'tenor': Period("9Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x104072b20> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103eec3c0> >, 'convention': 1, 'endOfMonth': False, 'settlementDays': 2, 'discountCurve': 'CLP_COLLUSD', 'index': 'ICP', 'fixedLegCurrency': <ORE.ORE.CLFCurrency; proxy of <Swig Object of type 'QuantExt::CLFCurrency *' at 0x10403d4a0> >, 'fwdStart': Period("0D"), 'fixedLegFrequency': 2}
# {'tenor': Period("10Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403e340> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12d00> >, 'convention': 1, 'endOfMonth': False, 'settlementDays': 2, 'discountCurve': 'CLP_COLLUSD', 'index': 'ICP', 'fixedLegCurrency': <ORE.ORE.CLFCurrency; proxy of <Swig Object of type 'QuantExt::CLFCurrency *' at 0x103f12850> >, 'fwdStart': Period("0D"), 'fixedLegFrequency': 2}
# {'tenor': Period("15Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103eed830> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x104071e90> >, 'convention': 1, 'endOfMonth': False, 'settlementDays': 2, 'discountCurve': 'CLP_COLLUSD', 'index': 'ICP', 'fixedLegCurrency': <ORE.ORE.CLFCurrency; proxy of <Swig Object of type 'QuantExt::CLFCurrency *' at 0x1040734b0> >, 'fwdStart': Period("0D"), 'fixedLegFrequency': 2}
# {'tenor': Period("20Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f125e0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f10270> >, 'convention': 1, 'endOfMonth': False, 'settlementDays': 2, 'discountCurve': 'CLP_COLLUSD', 'index': 'ICP', 'fixedLegCurrency': <ORE.ORE.CLFCurrency; proxy of <Swig Object of type 'QuantExt::CLFCurrency *' at 0x10403e2b0> >, 'fwdStart': Period("0D"), 'fixedLegFrequency': 2}
# {'tenor': Period("25Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x104072b20> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103eed830> >, 'convention': 1, 'endOfMonth': False, 'settlementDays': 2, 'discountCurve': 'CLP_COLLUSD', 'index': 'ICP', 'fixedLegCurrency': <ORE.ORE.CLFCurrency; proxy of <Swig Object of type 'QuantExt::CLFCurrency *' at 0x10403d4a0> >, 'fwdStart': Period("0D"), 'fixedLegFrequency': 2}
# {'tenor': Period("30Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403e340> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12d00> >, 'convention': 1, 'endOfMonth': False, 'settlementDays': 2, 'discountCurve': 'CLP_COLLUSD', 'index': 'ICP', 'fixedLegCurrency': <ORE.ORE.CLFCurrency; proxy of <Swig Object of type 'QuantExt::CLFCurrency *' at 0x103f12850> >, 'fwdStart': Period("0D"), 'fixedLegFrequency': 2}
# {'tenor': Period("1W"), 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103eec3c0> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': True, 'convention': 0, 'collateralCurve': 'SOFR', 'settlementDays': 0}
# {'tenor': Period("2W"), 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12850> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': True, 'convention': 0, 'collateralCurve': 'SOFR', 'settlementDays': 0}
# {'tenor': Period("1M"), 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403ca80> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': True, 'convention': 0, 'collateralCurve': 'SOFR', 'settlementDays': 0}
# {'tenor': Period("2M"), 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12dc0> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': True, 'convention': 0, 'collateralCurve': 'SOFR', 'settlementDays': 0}
# {'tenor': Period("3M"), 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403def0> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': True, 'convention': 0, 'collateralCurve': 'SOFR', 'settlementDays': 0}
# {'tenor': Period("4M"), 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12850> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': True, 'convention': 0, 'collateralCurve': 'SOFR', 'settlementDays': 0}
# {'tenor': Period("5M"), 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403ca80> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': True, 'convention': 0, 'collateralCurve': 'SOFR', 'settlementDays': 0}
# {'tenor': Period("6M"), 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12dc0> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': True, 'convention': 0, 'collateralCurve': 'SOFR', 'settlementDays': 0}
# {'tenor': Period("9M"), 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403def0> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': True, 'convention': 0, 'collateralCurve': 'SOFR', 'settlementDays': 0}
# {'tenor': Period("12M"), 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12850> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': True, 'convention': 0, 'collateralCurve': 'SOFR', 'settlementDays': 0}
# {'tenor': Period("18M"), 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403ca80> >, 'fixingDays': 0, 'endOfMonth': False, 'baseCurrencyAsCollateral': True, 'convention': 0, 'collateralCurve': 'SOFR', 'settlementDays': 0}
# {'tenor': Period("2Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12dc0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403c990> >, 'convention': 1, 'endOfMonth': False, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'SOFR', 'fixedLegCurrency': <ORE.ORE.CLPCurrency; proxy of <Swig Object of type 'QuantLib::CLPCurrency *' at 0x10403e340> >, 'fwdStart': Period("0D"), 'fixedLegFrequency': 2}
# {'tenor': Period("3Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103eec3c0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x104071e90> >, 'convention': 1, 'endOfMonth': False, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'SOFR', 'fixedLegCurrency': <ORE.ORE.CLPCurrency; proxy of <Swig Object of type 'QuantLib::CLPCurrency *' at 0x1040734b0> >, 'fwdStart': Period("0D"), 'fixedLegFrequency': 2}
# {'tenor': Period("4Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403e310> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403c9c0> >, 'convention': 1, 'endOfMonth': False, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'SOFR', 'fixedLegCurrency': <ORE.ORE.CLPCurrency; proxy of <Swig Object of type 'QuantLib::CLPCurrency *' at 0x103f127c0> >, 'fwdStart': Period("0D"), 'fixedLegFrequency': 2}
# {'tenor': Period("5Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x104072b20> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103eec3c0> >, 'convention': 1, 'endOfMonth': False, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'SOFR', 'fixedLegCurrency': <ORE.ORE.CLPCurrency; proxy of <Swig Object of type 'QuantLib::CLPCurrency *' at 0x10403ca80> >, 'fwdStart': Period("0D"), 'fixedLegFrequency': 2}
# {'tenor': Period("6Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12dc0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403c990> >, 'convention': 1, 'endOfMonth': False, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'SOFR', 'fixedLegCurrency': <ORE.ORE.CLPCurrency; proxy of <Swig Object of type 'QuantLib::CLPCurrency *' at 0x10403e340> >, 'fwdStart': Period("0D"), 'fixedLegFrequency': 2}
# {'tenor': Period("7Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103eed830> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x104071e90> >, 'convention': 1, 'endOfMonth': False, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'SOFR', 'fixedLegCurrency': <ORE.ORE.CLPCurrency; proxy of <Swig Object of type 'QuantLib::CLPCurrency *' at 0x1040734b0> >, 'fwdStart': Period("0D"), 'fixedLegFrequency': 2}
# {'tenor': Period("8Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403e310> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403c9c0> >, 'convention': 1, 'endOfMonth': False, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'SOFR', 'fixedLegCurrency': <ORE.ORE.CLPCurrency; proxy of <Swig Object of type 'QuantLib::CLPCurrency *' at 0x103f127c0> >, 'fwdStart': Period("0D"), 'fixedLegFrequency': 2}
# {'tenor': Period("9Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x104072b20> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103eed830> >, 'convention': 1, 'endOfMonth': False, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'SOFR', 'fixedLegCurrency': <ORE.ORE.CLPCurrency; proxy of <Swig Object of type 'QuantLib::CLPCurrency *' at 0x10403ca80> >, 'fwdStart': Period("0D"), 'fixedLegFrequency': 2}
# {'tenor': Period("10Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12dc0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403c990> >, 'convention': 1, 'endOfMonth': False, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'SOFR', 'fixedLegCurrency': <ORE.ORE.CLPCurrency; proxy of <Swig Object of type 'QuantLib::CLPCurrency *' at 0x10403e340> >, 'fwdStart': Period("0D"), 'fixedLegFrequency': 2}
# {'tenor': Period("15Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103eec3c0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x104071e90> >, 'convention': 1, 'endOfMonth': False, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'SOFR', 'fixedLegCurrency': <ORE.ORE.CLPCurrency; proxy of <Swig Object of type 'QuantLib::CLPCurrency *' at 0x1040734b0> >, 'fwdStart': Period("0D"), 'fixedLegFrequency': 2}
# {'tenor': Period("20Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403e310> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403c9c0> >, 'convention': 1, 'endOfMonth': False, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'SOFR', 'fixedLegCurrency': <ORE.ORE.CLPCurrency; proxy of <Swig Object of type 'QuantLib::CLPCurrency *' at 0x103f127c0> >, 'fwdStart': Period("0D"), 'fixedLegFrequency': 2}
# {'tenor': Period("25Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x104072b20> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103eec3c0> >, 'convention': 1, 'endOfMonth': False, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'SOFR', 'fixedLegCurrency': <ORE.ORE.CLPCurrency; proxy of <Swig Object of type 'QuantLib::CLPCurrency *' at 0x10403ca80> >, 'fwdStart': Period("0D"), 'fixedLegFrequency': 2}
# {'tenor': Period("30Y"), 'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12dc0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403c990> >, 'convention': 1, 'endOfMonth': False, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'SOFR', 'fixedLegCurrency': <ORE.ORE.CLPCurrency; proxy of <Swig Object of type 'QuantLib::CLPCurrency *' at 0x10403e340> >, 'fwdStart': Period("0D"), 'fixedLegFrequency': 2}
# {'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12640> >, 'tenor': Period("1M"), 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x104071e90> >, 'settlementDays': 0, 'endOfMonth': False, 'convention': 4}
# {'tenor': Period("3M"), 'longIndex': 'LIBOR3M', 'shortIndex': 'LIBOR1M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("6M"), 'longIndex': 'LIBOR3M', 'shortIndex': 'LIBOR1M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("9M"), 'longIndex': 'LIBOR3M', 'shortIndex': 'LIBOR1M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("1Y"), 'longIndex': 'LIBOR3M', 'shortIndex': 'LIBOR1M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("18M"), 'longIndex': 'LIBOR3M', 'shortIndex': 'LIBOR1M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("2Y"), 'longIndex': 'LIBOR3M', 'shortIndex': 'LIBOR1M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("3Y"), 'longIndex': 'LIBOR3M', 'shortIndex': 'LIBOR1M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("4Y"), 'longIndex': 'LIBOR3M', 'shortIndex': 'LIBOR1M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("5Y"), 'longIndex': 'LIBOR3M', 'shortIndex': 'LIBOR1M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("6Y"), 'longIndex': 'LIBOR3M', 'shortIndex': 'LIBOR1M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("7Y"), 'longIndex': 'LIBOR3M', 'shortIndex': 'LIBOR1M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("10Y"), 'longIndex': 'LIBOR3M', 'shortIndex': 'LIBOR1M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("12Y"), 'longIndex': 'LIBOR3M', 'shortIndex': 'LIBOR1M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("15Y"), 'longIndex': 'LIBOR3M', 'shortIndex': 'LIBOR1M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("20Y"), 'longIndex': 'LIBOR3M', 'shortIndex': 'LIBOR1M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("25Y"), 'longIndex': 'LIBOR3M', 'shortIndex': 'LIBOR1M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("30Y"), 'longIndex': 'LIBOR3M', 'shortIndex': 'LIBOR1M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403def0> >, 'tenor': Period("1M"), 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403c990> >, 'settlementDays': 0, 'endOfMonth': False, 'convention': 4}
# {'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403e2b0> >, 'tenor': Period("3M"), 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f12dc0> >, 'settlementDays': 0, 'endOfMonth': False, 'convention': 4}
# {'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403c9c0> >, 'tenor': Period("6M"), 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403def0> >, 'settlementDays': 0, 'endOfMonth': False, 'convention': 4}
# {'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x10403e310> >, 'tenor': Period("12M"), 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f10210> >, 'settlementDays': 0, 'endOfMonth': False, 'convention': 4}
# {'tenor': Period("2Y"), 'dayCounter': <ORE.ORE.Thirty360; proxy of <Swig Object of type 'QuantLib::Thirty360 *' at 0x10403d620> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403c9c0> >, 'frequency': 2, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'LIBOR3M', 'endOfMonth': False, 'convention': 4, 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("3Y"), 'dayCounter': <ORE.ORE.Thirty360; proxy of <Swig Object of type 'QuantLib::Thirty360 *' at 0x103f12dc0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e2b0> >, 'frequency': 2, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'LIBOR3M', 'endOfMonth': False, 'convention': 4, 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("4Y"), 'dayCounter': <ORE.ORE.Thirty360; proxy of <Swig Object of type 'QuantLib::Thirty360 *' at 0x10403c9c0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403d620> >, 'frequency': 2, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'LIBOR3M', 'endOfMonth': False, 'convention': 4, 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("5Y"), 'dayCounter': <ORE.ORE.Thirty360; proxy of <Swig Object of type 'QuantLib::Thirty360 *' at 0x103f127c0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f10210> >, 'frequency': 2, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'LIBOR3M', 'endOfMonth': False, 'convention': 4, 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("6Y"), 'dayCounter': <ORE.ORE.Thirty360; proxy of <Swig Object of type 'QuantLib::Thirty360 *' at 0x10403d620> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403c9c0> >, 'frequency': 2, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'LIBOR3M', 'endOfMonth': False, 'convention': 4, 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("7Y"), 'dayCounter': <ORE.ORE.Thirty360; proxy of <Swig Object of type 'QuantLib::Thirty360 *' at 0x103f12dc0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e2b0> >, 'frequency': 2, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'LIBOR3M', 'endOfMonth': False, 'convention': 4, 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("8Y"), 'dayCounter': <ORE.ORE.Thirty360; proxy of <Swig Object of type 'QuantLib::Thirty360 *' at 0x10403c9c0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403d620> >, 'frequency': 2, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'LIBOR3M', 'endOfMonth': False, 'convention': 4, 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("9Y"), 'dayCounter': <ORE.ORE.Thirty360; proxy of <Swig Object of type 'QuantLib::Thirty360 *' at 0x103f127c0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f10210> >, 'frequency': 2, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'LIBOR3M', 'endOfMonth': False, 'convention': 4, 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("10Y"), 'dayCounter': <ORE.ORE.Thirty360; proxy of <Swig Object of type 'QuantLib::Thirty360 *' at 0x10403d620> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403c9c0> >, 'frequency': 2, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'LIBOR3M', 'endOfMonth': False, 'convention': 4, 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("11Y"), 'dayCounter': <ORE.ORE.Thirty360; proxy of <Swig Object of type 'QuantLib::Thirty360 *' at 0x103f12dc0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e2b0> >, 'frequency': 2, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'LIBOR3M', 'endOfMonth': False, 'convention': 4, 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("12Y"), 'dayCounter': <ORE.ORE.Thirty360; proxy of <Swig Object of type 'QuantLib::Thirty360 *' at 0x10403c9c0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403d620> >, 'frequency': 2, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'LIBOR3M', 'endOfMonth': False, 'convention': 4, 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("15Y"), 'dayCounter': <ORE.ORE.Thirty360; proxy of <Swig Object of type 'QuantLib::Thirty360 *' at 0x103f127c0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f10210> >, 'frequency': 2, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'LIBOR3M', 'endOfMonth': False, 'convention': 4, 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("20Y"), 'dayCounter': <ORE.ORE.Thirty360; proxy of <Swig Object of type 'QuantLib::Thirty360 *' at 0x10403d620> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403c9c0> >, 'frequency': 2, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'LIBOR3M', 'endOfMonth': False, 'convention': 4, 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("25Y"), 'dayCounter': <ORE.ORE.Thirty360; proxy of <Swig Object of type 'QuantLib::Thirty360 *' at 0x103f12dc0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e2b0> >, 'frequency': 2, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'LIBOR3M', 'endOfMonth': False, 'convention': 4, 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("30Y"), 'dayCounter': <ORE.ORE.Thirty360; proxy of <Swig Object of type 'QuantLib::Thirty360 *' at 0x10403c9c0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403d620> >, 'frequency': 2, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'LIBOR3M', 'endOfMonth': False, 'convention': 4, 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("40Y"), 'dayCounter': <ORE.ORE.Thirty360; proxy of <Swig Object of type 'QuantLib::Thirty360 *' at 0x103f127c0> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x103f10210> >, 'frequency': 2, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'LIBOR3M', 'endOfMonth': False, 'convention': 4, 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'tenor': Period("50Y"), 'dayCounter': <ORE.ORE.Thirty360; proxy of <Swig Object of type 'QuantLib::Thirty360 *' at 0x10403d620> >, 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403c9c0> >, 'frequency': 2, 'settlementDays': 2, 'discountCurve': 'SOFR', 'index': 'LIBOR3M', 'endOfMonth': False, 'convention': 4, 'fixedLegFrequency': 2, 'fwdStart': Period("0D")}
# {'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f12d00> >, 'tenor': Period("6M"), 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e2b0> >, 'settlementDays': 0, 'endOfMonth': False, 'convention': 4}
# {'tenor': Period("1Y"), 'longIndex': 'LIBOR6M', 'shortIndex': 'LIBOR3M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("18M"), 'longIndex': 'LIBOR6M', 'shortIndex': 'LIBOR3M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("2Y"), 'longIndex': 'LIBOR6M', 'shortIndex': 'LIBOR3M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("3Y"), 'longIndex': 'LIBOR6M', 'shortIndex': 'LIBOR3M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("4Y"), 'longIndex': 'LIBOR6M', 'shortIndex': 'LIBOR3M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("5Y"), 'longIndex': 'LIBOR6M', 'shortIndex': 'LIBOR3M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("7Y"), 'longIndex': 'LIBOR6M', 'shortIndex': 'LIBOR3M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("10Y"), 'longIndex': 'LIBOR6M', 'shortIndex': 'LIBOR3M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("12Y"), 'longIndex': 'LIBOR6M', 'shortIndex': 'LIBOR3M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("15Y"), 'longIndex': 'LIBOR6M', 'shortIndex': 'LIBOR3M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("20Y"), 'longIndex': 'LIBOR6M', 'shortIndex': 'LIBOR3M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("25Y"), 'longIndex': 'LIBOR6M', 'shortIndex': 'LIBOR3M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("30Y"), 'longIndex': 'LIBOR6M', 'shortIndex': 'LIBOR3M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'dayCounter': <ORE.ORE.Actual360; proxy of <Swig Object of type 'QuantLib::Actual360 *' at 0x103f10210> >, 'tenor': Period("12M"), 'calendar': <ORE.ORE.NullCalendar; proxy of <Swig Object of type 'QuantLib::NullCalendar *' at 0x10403e310> >, 'settlementDays': 0, 'endOfMonth': False, 'convention': 4}
# {'tenor': Period("2Y"), 'longIndex': 'LIBOR12M', 'shortIndex': 'LIBOR3M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("3Y"), 'longIndex': 'LIBOR12M', 'shortIndex': 'LIBOR3M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("4Y"), 'longIndex': 'LIBOR12M', 'shortIndex': 'LIBOR3M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("5Y"), 'longIndex': 'LIBOR12M', 'shortIndex': 'LIBOR3M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("7Y"), 'longIndex': 'LIBOR12M', 'shortIndex': 'LIBOR3M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("10Y"), 'longIndex': 'LIBOR12M', 'shortIndex': 'LIBOR3M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("12Y"), 'longIndex': 'LIBOR12M', 'shortIndex': 'LIBOR3M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("15Y"), 'longIndex': 'LIBOR12M', 'shortIndex': 'LIBOR3M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("20Y"), 'longIndex': 'LIBOR12M', 'shortIndex': 'LIBOR3M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("25Y"), 'longIndex': 'LIBOR12M', 'shortIndex': 'LIBOR3M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}
# {'tenor': Period("30Y"), 'longIndex': 'LIBOR12M', 'shortIndex': 'LIBOR3M', 'discountCurve': 'SOFR', 'spreadOnShortIndex': True}

# %%
from parsing.enums import *
from collections import deque


def getDependencyList(data: dict) -> dict:
    # possible curve related keys
    pc = ['discountCurve', 'discountingCurve', 'collateralCurve']
    # possible index related keys
    pi = ['index', 'shortIndex', 'longIndex']

    dependecies = {}
    for curve in data['curves']:
        curveName = curve['curveName']
        if curveName not in dependecies.keys():
            dependecies[curveName] = set()

        curveConfig = curve['curveConfig']
        curveType = CurveType(curveConfig['curveType'])
        if curveType == CurveType.Piecewise:
            for rateHelper in curveConfig['rateHelpers']:
                config = rateHelper['helperConfig']
                for key in pc:
                    if key in config.keys():
                        dependecies[curveName].add(config[key])
                for key in pi:
                    if key in config.keys():
                        dependecies[curveName].add(config[key])
    return dependecies


dependencies = getDependencyList(file)
dependencies
# Out:
# {'ICP': {'CLP_COLLUSD', 'ICP'},
#  'SOFR': {'SOFR'},
#  'UF_COLLUSD': {'CLP_COLLUSD', 'ICP'},
#  'CLP_COLLUSD': {'SOFR'},
#  'LIBOR1M': {'LIBOR1M', 'LIBOR3M', 'SOFR'},
#  'LIBOR3M': {'LIBOR3M', 'SOFR'},
#  'LIBOR6M': {'LIBOR3M', 'LIBOR6M', 'SOFR'},
#  'LIBOR12M': {'LIBOR12M', 'LIBOR3M', 'SOFR'}}

# %%
def topologicalSort(dependencies):

    for element, deps in dependencies.items():
        deps.discard(element)

    # Find elements with no dependencies
    noDependency = deque([k for k, v in dependencies.items() if not v])

    sortedElements = []

    while noDependency:
        currentElement = noDependency.popleft()
        sortedElements.append(currentElement)

        # Remove the current element as a dependency from other elements
        for element, deps in dependencies.items():
            if currentElement in deps:
                deps.remove(currentElement)
                # If the element now has no dependencies, add it to the queue
                if not deps and element not in noDependency:
                    noDependency.append(element)

    return sortedElements

# %%
sortedList = topologicalSort(dependencies)
# Out:
# ['SOFR',
#  'CLP_COLLUSD',
#  'LIBOR3M',
#  'ICP',
#  'LIBOR1M',
#  'LIBOR6M',
#  'LIBOR12M',
#  'UF_COLLUSD']
